# %%
import numpy as np
import pandas as pd

from sklearn.impute import SimpleImputer

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('cleandiabetes.csv')

df.head()
# Out:
#    Unnamed: 0  Pregnancies  Glucose  ...  DiabetesPedigreeFunction   Age  Outcome
# 0           0          6.0    148.0  ...                     0.627  50.0        1
# 1           1          1.0     85.0  ...                     0.351  31.0        0
# 2           2          8.0    183.0  ...                     0.672  32.0        1
# 3           3          1.0     89.0  ...                     0.167  21.0        0
# 4           4          0.0    137.0  ...                     2.288  33.0        1
#
# [5 rows x 10 columns]

# %% [markdown]
# ## Contaminating data with missing values
# ### Split data into Features & Corresponding label

# %%
df_features = df.drop('Outcome', axis=1)
df_label = df[['Outcome']]

df_features.head()
# Out:
#    Unnamed: 0  Pregnancies  Glucose  ...   BMI  DiabetesPedigreeFunction   Age
# 0           0          6.0    148.0  ...  33.6                     0.627  50.0
# 1           1          1.0     85.0  ...  26.6                     0.351  31.0
# 2           2          8.0    183.0  ...  23.3                     0.672  32.0
# 3           3          1.0     89.0  ...  28.1                     0.167  21.0
# 4           4          0.0    137.0  ...  43.1                     2.288  33.0
#
# [5 rows x 9 columns]

# %%
df_label.head()
# Out:
#    Outcome
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1

# %% [markdown]
# ### Made a mask using random with contains 1 True in 100 False

# %%
mask = np.random.randint(0, 100, size=df_features.shape).astype(np.bool)

mask
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True, False,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True, False,  True, ...,  True,  True,  True]])

# %%
mask = np.logical_not(mask)

mask
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False,  True, False, ..., False, False, False]])

# %%
df_features.head()
# Out:
#    Unnamed: 0  Pregnancies  Glucose  ...   BMI  DiabetesPedigreeFunction   Age
# 0           0          6.0    148.0  ...  33.6                     0.627  50.0
# 1           1          1.0     85.0  ...  26.6                     0.351  31.0
# 2           2          8.0    183.0  ...  23.3                     0.672  32.0
# 3           3          1.0     89.0  ...  28.1                     0.167  21.0
# 4           4          0.0    137.0  ...  43.1                     2.288  33.0
#
# [5 rows x 9 columns]

# %%
print(df_features.shape)
print(mask.shape)
# Out:
# (768, 9)
# (768, 9)

# %% [markdown]
# ### Loaded Imputation in Dataset as NaN

# %%
df_features[mask] = np.nan

df_features.sample(15)
# Out:
#      Unnamed: 0  Pregnancies  Glucose  ...   BMI  DiabetesPedigreeFunction   Age
# 753       753.0          0.0    181.0  ...  43.3                     0.222  26.0
# 209       209.0          7.0    184.0  ...  35.5                     0.355  41.0
# 738       738.0          2.0     99.0  ...  36.6                     0.453  21.0
# 690       690.0          8.0    107.0  ...  24.6                     0.856  34.0
# 716       716.0          3.0    173.0  ...  33.8                     0.970  31.0
# 348       348.0          3.0     99.0  ...  21.8                     0.279  26.0
# 475       475.0          0.0    137.0  ...  27.3                     0.231  59.0
# 86         86.0         13.0    106.0  ...  36.6                     0.178  45.0
# 501       501.0          3.0     84.0  ...  37.2                     0.267  28.0
# 286       286.0          5.0    155.0  ...  38.7                     0.619  34.0
# 324       324.0          2.0    112.0  ...  35.7                     0.148  21.0
# 58         58.0          0.0    146.0  ...  40.5                     1.781  44.0
# 260       260.0          3.0    191.0  ...  30.9                     0.299  34.0
# 13         13.0          1.0    189.0  ...  30.1                     0.398  59.0
# 441       441.0          2.0     83.0  ...  32.2                     0.497  22.0
#
# [15 rows x 9 columns]

# %% [markdown]
# ### Saving Impure Dataset

# %%
df_features.to_csv('ImputedDiabetes.csv')

# %% [markdown]
# ## Feature Imputation Pipeline

# %%
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score

# %%
x_train, x_test, y_train, y_test = train_test_split(df_features, df_label, test_size=0.2)

# %% [markdown]
# ### Transform Data into Impute Missing values

# %%
transform = ColumnTransformer(
    transformers=[('features', SimpleImputer(strategy='mean'), [ 0, 1, 2, 3, 4, 5, 6, 7]) ]
)

# %% [markdown]
# ### Create sklearn pipeline to transform data to impute missing values & fit DecisionTreeClassifier

# %%
clf = make_pipeline(transform, DecisionTreeClassifier(max_depth=4))

# %%
clf = clf.fit(x_train, y_train)

clf.score(x_train, y_train)
# Out:
# 0.8403908794788274

# %%
y_pred = clf.predict(x_test)

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.6623376623376623
