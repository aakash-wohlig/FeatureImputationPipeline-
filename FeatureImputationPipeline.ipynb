# %%
import numpy as np
import pandas as pd

from sklearn.impute import SimpleImputer

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('diabetes.csv')

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %% [markdown]
# ## Contaminating data with missing values
# ### Split data into Features & Corresponding label

# %%
df_features = df.drop('Outcome', axis=1)
df_label = df[['Outcome']]

df_features.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0            6      148             72  ...  33.6                     0.627   50
# 1            1       85             66  ...  26.6                     0.351   31
# 2            8      183             64  ...  23.3                     0.672   32
# 3            1       89             66  ...  28.1                     0.167   21
# 4            0      137             40  ...  43.1                     2.288   33
#
# [5 rows x 8 columns]

# %%
df_label.head()
# Out:
#    Outcome
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1

# %% [markdown]
# ### Made a mask using random with contains 1 True in 100 False

# %%
mask = np.random.randint(0, 100, size=df_features.shape).astype(np.bool)

mask
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True, False],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
mask = np.logical_not(mask)

mask
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False,  True],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
df_features = df_features.drop('mask', axis=1)
df_features.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0            6      148             72  ...  33.6                     0.627   50
# 1            1       85             66  ...  26.6                     0.351   31
# 2            8      183             64  ...  23.3                     0.672   32
# 3            1       89             66  ...  28.1                     0.167   21
# 4            0      137             40  ...  43.1                     2.288   33
#
# [5 rows x 8 columns]

# %%
print(df_features.shape)
print(mask.shape)
# Out:
# (768, 8)
# (768, 8)

# %% [markdown]
# ### Loaded Imputation in Dataset as NaN

# %%
df_features[mask] = np.nan

df_features.sample(15)
# Out:
#      Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction   Age
# 558         11.0    103.0           68.0  ...  46.2                     0.126  42.0
# 454          2.0    100.0           54.0  ...  37.8                     0.498   NaN
# 195          5.0    158.0           84.0  ...  39.4                     0.395  29.0
# 297          0.0    126.0           84.0  ...  30.7                     0.520  24.0
# 235          4.0    171.0           72.0  ...  43.6                     0.479  26.0
# 96           2.0     92.0           62.0  ...  31.6                     0.130  24.0
# 228          4.0    197.0           70.0  ...  36.7                     2.329  31.0
# 746          1.0    147.0           94.0  ...  49.3                     0.358  27.0
# 134          2.0     96.0           68.0  ...  21.1                     0.647  26.0
# 503          7.0     94.0           64.0  ...  33.3                     0.738  41.0
# 23           9.0    119.0           80.0  ...  29.0                     0.263  29.0
# 747          1.0     81.0           74.0  ...  46.3                     1.096  32.0
# 711          5.0    126.0           78.0  ...  29.6                     0.439  40.0
# 556          1.0     97.0           70.0  ...  38.1                     0.218  30.0
# 418          1.0     83.0           68.0  ...  18.2                     0.624  27.0
#
# [15 rows x 8 columns]

# %% [markdown]
# ### Saving Impure Dataset

# %%
df_features.to_csv('ImputedDiabetes.csv')

# %% [markdown]
# ## Feature Imputation Pipeline

# %%
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score

# %%
x_train, x_test, y_train, y_test = train_test_split(df_features, df_label, test_size=0.2)

# %% [markdown]
# ### Transform Data into Impute Missing values

# %%
transform = ColumnTransformer(
    transformers=[('features', SimpleImputer(strategy='mean'), [ 0, 1, 2, 3, 4, 5, 6, 7]) ]
)

# %% [markdown]
# ### Create sklearn pipeline to transform data to impute missing values & fit DecisionTreeClassifier

# %%
clf = make_pipeline(transform, DecisionTreeClassifier(max_depth=4))

# %%
clf = clf.fit(x_train, y_train)

clf.score(x_train, y_train)
# Out:
# 0.8078175895765473

# %%
y_pred = clf.predict(x_test)

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.7337662337662337
